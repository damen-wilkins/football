# %%
#Imports
import pandas as pd
from pathlib import Path

#Config / Settings
BASE = Path(r"C:\Users\damen\Desktop\football-main")

PROJ_DIR = BASE / "Projections"
ACT_DIRS = {
    'QB': BASE / r"Actuals\QB Stats",
    'RB': BASE / r"Actuals\RB Stats",
    'WR': BASE / r"Actuals\WR Stats",
    'TE': BASE / r"Actuals\TE Stats",
}

YEARS = range(2016, 2025)  # include 2016–2024
POSITIONS = ['QB', 'RB', 'WR', 'TE']

# Season game counts
SEASON_GAMES = {
    2016: 16, 2017: 16, 2018: 16, 2019: 16, 2020: 16,
    2021: 17, 2022: 17, 2023: 17, 2024: 17
}

# Projections loader
def load_projections(position: str, years=YEARS) -> pd.DataFrame:
    frames = []
    for y in years:
        df = pd.read_csv(PROJ_DIR / f"projections_{y}_wk0.csv")[['player','position','points']].copy()
        df['season'] = y
        df['player'] = df['player'].astype(str).str.strip()
        df = df[df['position'].str.upper() == position]
        frames.append(df)
    return pd.concat(frames, ignore_index=True)

# Actuals loader
def load_actuals(position: str, years=YEARS) -> pd.DataFrame:
    frames = []
    for y in years:
        df = pd.read_csv(ACT_DIRS[position] / f"{y} {position} Stats", sep=None, engine='python')
        df = df.rename(columns={'Player':'player'})[['player','FPTS']].copy()
        df['player'] = (
            df['player'].astype(str)
            .str.replace(r"\s*\([^)]*\)$", "", regex=True)  # strip (TEAM)
            .str.strip()
        )
        df['season'] = y
        df['position'] = position
        frames.append(df)
    return pd.concat(frames, ignore_index=True)

# Panel builder (all years for one position)
def build_panel(position: str) -> pd.DataFrame:
    proj = load_projections(position)
    act = load_actuals(position)
    panel = (
        proj.merge(
            act[['player','season','FPTS']],
            on=['player','season'],
            how='inner'
        )
        .rename(columns={'points':'proj_points','FPTS':'actual_FPTS'})
    )
    panel['error'] = panel['proj_points'] - panel['actual_FPTS']
    panel['error_pct'] = panel['error'] / panel['proj_points']
    return panel

# Stack all positions + years
def build_all_panels(positions=POSITIONS) -> pd.DataFrame:
    return pd.concat([build_panel(pos) for pos in positions], ignore_index=True)

# ---- RUN IT ----
all_data = build_all_panels()
all_data.head()
# Out:
#            player position  proj_points  season  actual_FPTS  error  error_pct
# 0      Cam Newton       QB        391.0    2016        254.3  136.7   0.349616
# 1   Aaron Rodgers       QB        386.0    2016        380.0    6.0   0.015544
# 2  Russell Wilson       QB        374.0    2016        270.1  103.9   0.277807
# 3     Andrew Luck       QB        365.0    2016        307.6   57.4   0.157260
# 4      Drew Brees       QB        352.0    2016        332.3   19.7   0.055966

# %%
# Position-level metrics from historical stacked data (all_data)
pos_metrics = (
    all_data
    .groupby('position')
    .agg(
        avg_proj=('proj_points','mean'),
        avg_actual=('actual_FPTS','mean'),
        bias=('error','mean'),                       # systematic over/under
        abs_miss=('error', lambda x: x.abs().mean()),# typical miss size
        error_std=('error','std')                    # volatility of misses
    )
    .reset_index()
)

# Reliability: lower spread relative to projection = more reliable
pos_metrics['reliability'] = 1 - (pos_metrics['error_std'] / pos_metrics['avg_proj'])
pos_metrics
# Out:
#   position    avg_proj  avg_actual       bias   abs_miss  error_std  \
# 0       QB  288.465385  218.621474  69.843910  90.697756  90.385964
# 1       RB  159.308084  135.142531  24.165554  59.709315  73.546528
# 2       TE  136.419136  112.951543  23.467593  46.611420  54.053487
# 3       WR  197.449735  166.252205  31.197531  57.628219  67.294367
#
#    reliability
# 0     0.686666
# 1     0.538338
# 2     0.603769
# 3     0.659182

# %%
# Load current-season projections (2025 if available, else 2024)
for y in (2025, 2024):
    try:
        proj_current = pd.read_csv(PROJ_DIR / f"projections_{y}_wk0.csv")[['player','position','points']].copy()
        proj_current['season'] = y
        CURRENT_YEAR = y
        break
    except FileNotFoundError:
        continue

print(f"Using projections for {CURRENT_YEAR}")
proj_current.head()
# Out:
# Using projections for 2025
#            player position  points  season
# 0  Bijan Robinson       RB   332.0    2025
# 1  Saquon Barkley       RB   319.0    2025
# 2    Jahmyr Gibbs       RB   318.0    2025
# 3   Ja'Marr Chase       WR   355.0    2025
# 4   Lamar Jackson       QB   438.0    2025

# %%
# Merge position-level bias/reliability/abs_miss into current projections
proj_current = proj_current.merge(
    pos_metrics[['position','bias','reliability','abs_miss']],
    on='position', how='left'
)

# Adjust projections with historical bias & reliability
proj_current['adj_points']  = (proj_current['points'] - proj_current['bias']) * proj_current['reliability']

# Tier score: reward adjusted points; penalize historically noisy positions
proj_current['tier_score'] = proj_current['adj_points'] / (proj_current['abs_miss'] + 1e-6)

proj_current[['player','position','points','adj_points','tier_score']].head()
# Out:
#            player position  points  adj_points  tier_score
# 0  Bijan Robinson       RB   332.0  165.718905    2.775428
# 1  Saquon Barkley       RB   319.0  158.720514    2.658220
# 2    Jahmyr Gibbs       RB   318.0  158.182177    2.649204
# 3   Ja'Marr Chase       WR   355.0  213.444853    3.703825
# 4   Lamar Jackson       QB   438.0  252.800332    2.787283

# %%
# Desired tiers per position
TIER_COUNTS = {'WR': 10, 'RB': 8, 'QB': 6, 'TE': 5}

def assign_tiers_by_position(df, tier_counts=TIER_COUNTS):
    out = []
    for pos, sub in df.groupby('position', group_keys=False):
        n = tier_counts.get(pos, 5)
        sub = sub.sort_values('tier_score', ascending=False).reset_index(drop=True)
        # percentile rank then cut into n bins (robust when few players)
        pr = sub.index / max(len(sub)-1, 1)
        sub['tier'] = pd.cut(pr, bins=n, labels=range(1, n+1), include_lowest=True)
        out.append(sub)
    return pd.concat(out, ignore_index=True)

proj_current_tiers = assign_tiers_by_position(proj_current)
proj_current_tiers[['player','position','points','adj_points','tier_score','tier']].head(20)
# Out:
#              player position  points  adj_points  tier_score  tier
# 0     Lamar Jackson       QB   438.0  252.800332    2.787283     1
# 1        Josh Allen       QB   432.0  248.680335    2.741858     1
# 2        Joe Burrow       QB   415.0  237.007010    2.613152     1
# 3    Jayden Daniels       QB   412.0  234.947012    2.590439     1
# 4       Jalen Hurts       QB   398.0  225.333685    2.484446     1
# 5    Baker Mayfield       QB   377.0  210.913696    2.325457     1
# 6   Patrick Mahomes       QB   376.0  210.227029    2.317886     2
# 7      Kyler Murray       QB   361.0  199.927037    2.204322     2
# 8            Bo Nix       QB   356.0  196.493706    2.166467     2
# 9       Brock Purdy       QB   352.0  193.747041    2.136183     2
# 10       Jared Goff       QB   346.0  189.627044    2.090758     2
# 11   Caleb Williams       QB   340.0  185.507047    2.045332     2
# 12   Justin Herbert       QB   338.0  184.133715    2.030190     3
# 13     Dak Prescott       QB   336.0  182.760383    2.015049     3
# 14    Justin Fields       QB   333.0  180.700384    1.992336     3
# 15    J.J. McCarthy       QB   323.0  173.833722    1.916626     3
# 16      Jordan Love       QB   323.0  173.833722    1.916626     3
# 17      C.J. Stroud       QB   320.0  171.773724    1.893914     3
# 18       Drake Maye       QB   319.0  171.087058    1.886343     4
# 19  Trevor Lawrence       QB   318.0  170.400392    1.878772     4

# %%
# Top 15 per position (adjusted)
def top_n(pos, n=15):
    cols = ['player','position','points','adj_points','tier_score','tier']
    return (proj_current_tiers.query("position == @pos")
            .sort_values('tier_score', ascending=False)
            [cols].head(n))

top_n('WR', 15)
# top_n('RB', 15); top_n('QB', 10); top_n('TE', 10)
# Out:
#                  player position  points  adj_points  tier_score  tier
# 144       Ja'Marr Chase       WR   355.0  213.444853    3.703825     1
# 145    Justin Jefferson       WR   317.0  188.395926    3.269161     1
# 146         CeeDee Lamb       WR   312.0  185.100015    3.211968     1
# 147          Puka Nacua       WR   305.0  180.485739    3.131899     1
# 148        Malik Nabers       WR   302.0  178.508192    3.097583     1
# 149   Amon-Ra St. Brown       WR   298.0  175.871462    3.051829     1
# 150        Nico Collins       WR   287.0  168.620457    2.926005     1
# 151    Brian Thomas Jr.       WR   284.0  166.642910    2.891689     1
# 152        Drake London       WR   268.0  156.095994    2.708673     2
# 153          A.J. Brown       WR   265.0  154.118447    2.674357     2
# 154         Tyreek Hill       WR   263.0  152.800082    2.651480     2
# 155       Ladd McConkey       WR   262.0  152.140900    2.640042     2
# 156  Jaxon Smith-Njigba       WR   255.0  147.526624    2.559972     2
# 157       Davante Adams       WR   251.0  144.889895    2.514218     2
# 158         Tee Higgins       WR   251.0  144.889895    2.514218     2

# %% [markdown]
# ##### Option 1.A - Weight reliability more heavily

# %%
# Option A.1 - reliability weighted more heavily
proj_current['tier_score_A1'] = (
    (proj_current['points'] - proj_current['bias'])
    * (proj_current['reliability'] ** 2)   # heavier weight on reliability
    / (proj_current['abs_miss'] + 1e-6)
)

# Assign tiers for this option (pass only the right column)
proj_tiers_A1 = assign_tiers_by_position(
    proj_current[['player','position','points','adj_points','tier_score_A1']].rename(columns={'tier_score_A1':'tier_score'})
)

# Preview top WRs under Option A.1
proj_tiers_A1.query("position == 'WR'")[['player','points','adj_points','tier_score','tier']].head(65)
# Out:
#                player  points  adj_points  tier_score  tier
# 144     Ja'Marr Chase   355.0  213.444853    2.441496     1
# 145  Justin Jefferson   317.0  188.395926    2.154973     1
# 146       CeeDee Lamb   312.0  185.100015    2.117273     1
# 147        Puka Nacua   305.0  180.485739    2.064492     1
# 148      Malik Nabers   302.0  178.508192    2.041872     1
# ..                ...     ...         ...         ...   ...
# 204      Amari Cooper   145.0   75.016572    0.858080     9
# 205    Xavier Legette   144.0   74.357390    0.850539     9
# 206   Demario Douglas   143.0   73.698208    0.842999     9
# 207    Marquise Brown   142.0   73.039025    0.835459     9
# 208       Romeo Doubs   142.0   73.039025    0.835459     9
#
# [65 rows x 5 columns]

# %%
def show_tiers_multi(df: pd.DataFrame, position: str, n: int = 30, per_col: int = 15):
    """
    Show top n players for a given position in multiple columns.
    Each column has `per_col` rows. Handles uneven last column.
    """
    # Get sorted slice (tier first, then score/points)
    table = (
        df.loc[df['position'] == position, ['player','points','tier_score','tier']]
          .sort_values(by=['tier','tier_score'], ascending=[True, False])
          .head(n)
          .reset_index(drop=True)
    )
    
    # Split into chunks
    chunks = [table.iloc[i:i+per_col].reset_index(drop=True) 
              for i in range(0, len(table), per_col)]
    
    # Rename columns for each chunk
    renamed = []
    for idx, c in enumerate(chunks, 1):
        c.columns = [f'player_{idx}', f'points_{idx}', f'tier_score_{idx}', f'tier_{idx}']
        renamed.append(c)
    
    return pd.concat(renamed, axis=1)

# Option A.1 - heavier reliability weight
proj_current['tier_score_A1'] = (
    (proj_current['points'] - proj_current['bias'])
    * (proj_current['reliability'] ** 2)
    / (proj_current['abs_miss'] + 1e-6)
)

proj_tiers_A1 = assign_tiers_by_position(
    proj_current[['player','position','points','adj_points','tier_score_A1']]
    .rename(columns={'tier_score_A1':'tier_score'})
)

# Example: top 72 WRs, 24 per column
show_tiers_multi(proj_tiers_A1, 'WR', n=72, per_col=24)
# Out:
#                player_1  points_1  tier_score_1  tier_1           player_2  \
# 0         Ja'Marr Chase     355.0      2.441496       1        Zay Flowers
# 1      Justin Jefferson     317.0      2.154973       1      Calvin Ridley
# 2           CeeDee Lamb     312.0      2.117273       1        Jerry Jeudy
# 3            Puka Nacua     305.0      2.064492       1        Rashee Rice
# 4          Malik Nabers     302.0      2.041872       1   Jameson Williams
# 5     Amon-Ra St. Brown     298.0      2.011712       1      Jaylen Waddle
# 6          Nico Collins     287.0      1.928771       1      Jakobi Meyers
# 7      Brian Thomas Jr.     284.0      1.906150       1     George Pickens
# 8          Drake London     268.0      1.785509       2      Travis Hunter
# 9            A.J. Brown     265.0      1.762889       2      Travis Hunter
# 10          Tyreek Hill     263.0      1.747809       2  Tetairoa McMillan
# 11        Ladd McConkey     262.0      1.740269       2        Chris Olave
# 12   Jaxon Smith-Njigba     255.0      1.687488       2        Rome Odunze
# 13        Davante Adams     251.0      1.657328       2       Deebo Samuel
# 14          Tee Higgins     251.0      1.657328       2     Jauan Jennings
# 15       Terry McLaurin     247.0      1.627168       3       Chris Godwin
# 16           Mike Evans     246.0      1.619627       3       Stefon Diggs
# 17       Garrett Wilson     244.0      1.604547       3      Khalil Shakir
# 18           D.J. Moore     241.0      1.581927       3        Cooper Kupp
# 19  Marvin Harrison Jr.     237.0      1.551767       3        Jayden Reed
# 20           DK Metcalf     233.0      1.521606       3     Jordan Addison
# 21     Courtland Sutton     230.0      1.498986       3     Matthew Golden
# 22        DeVonta Smith     229.0      1.491446       4    Michael Pittman
# 23        Xavier Worthy     226.0      1.468826       4     Ricky Pearsall
#
#     points_2  tier_score_2  tier_2           player_3  points_3  tier_score_3  \
# 0      221.0      1.431125       4         Josh Downs     179.0      1.114442
# 1      221.0      1.431125       4     Darnell Mooney     178.0      1.106902
# 2      219.0      1.416045       4     Rashid Shaheed     172.0      1.061662
# 3      215.0      1.385885       4       Keon Coleman     168.0      1.031501
# 4      214.0      1.378345       4       Keenan Allen     161.0      0.978721
# 5      211.0      1.355725       5       Adam Thielen     160.0      0.971181
# 6      210.0      1.348185       5  Wan'Dale Robinson     157.0      0.948560
# 7      209.0      1.340645       5     Rashod Bateman     153.0      0.918400
# 8      207.0      1.325564       5        Marvin Mims     153.0      0.918400
# 9      207.0      1.325564       5       Emeka Egbuka     152.0      0.910860
# 10     207.0      1.325564       5      Brandon Aiyuk     147.0      0.873160
# 11     203.0      1.295404       5     Cedric Tillman     147.0      0.873160
# 12     203.0      1.295404       5       Amari Cooper     145.0      0.858080
# 13     200.0      1.272784       6     Xavier Legette     144.0      0.850539
# 14     199.0      1.265244       6    Demario Douglas     143.0      0.842999
# 15     199.0      1.265244       6     Marquise Brown     142.0      0.835459
# 16     196.0      1.242624       6        Romeo Doubs     142.0      0.835459
# 17     191.0      1.204923       6     Jayden Higgins     140.0      0.820379
# 18     190.0      1.197383       6     Christian Kirk     140.0      0.820379
# 19     189.0      1.189843       6   Quentin Johnston     139.0      0.812839
# 20     189.0      1.189843       7     Michael Wilson     135.0      0.782679
# 21     187.0      1.174763       7      Luther Burden     126.0      0.714818
# 22     185.0      1.159683       7        Alec Pierce     125.0      0.707278
# 23     185.0      1.159683       7          Jack Bech     121.0      0.677118
#
#     tier_3
# 0        7
# 1        7
# 2        7
# 3        8
# 4        8
# 5        8
# 6        8
# 7        8
# 8        8
# 9        8
# 10       9
# 11       9
# 12       9
# 13       9
# 14       9
# 15       9
# 16       9
# 17      10
# 18      10
# 19      10
# 20      10
# 21      10
# 22      10
# 23      10

# %%
def show_tiers_multi(df: pd.DataFrame, position: str, n: int = 30, per_col: int = 15):
    """
    Show top n players for a given position in multiple columns.
    Each column has `per_col` rows. Handles uneven last column.
    """
    # Get sorted slice (tier first, then score/points)
    table = (
        df.loc[df['position'] == position, ['player','points','tier_score','tier']]
          .sort_values(by=['tier','tier_score'], ascending=[True, False])
          .head(n)
          .reset_index(drop=True)
    )
    
    # Split into chunks
    chunks = [table.iloc[i:i+per_col].reset_index(drop=True) 
              for i in range(0, len(table), per_col)]
    
    # Rename columns for each chunk
    renamed = []
    for idx, c in enumerate(chunks, 1):
        c.columns = [f'player_{idx}', f'points_{idx}', f'tier_score_{idx}', f'tier_{idx}']
        renamed.append(c)
    
    return pd.concat(renamed, axis=1)

# Option A.1 - heavier reliability weight
proj_current['tier_score_A1'] = (
    (proj_current['points'] - proj_current['bias'])
    * (proj_current['reliability'] ** 2)
    / (proj_current['abs_miss'] + 1e-6)
)

proj_tiers_A1 = assign_tiers_by_position(
    proj_current[['player','position','points','adj_points','tier_score_A1']]
    .rename(columns={'tier_score_A1':'tier_score'})
)

# Example: top 72 RBs, 24 per column
show_tiers_multi(proj_tiers_A1, 'RB', n=72, per_col=24)
# Out:
#                player_1  points_1  tier_score_1  tier_1             player_2  \
# 0        Bijan Robinson     332.0      1.494118       1     David Montgomery
# 1        Saquon Barkley     319.0      1.431020       1            Joe Mixon
# 2          Jahmyr Gibbs     318.0      1.426167       1         Tyrone Tracy
# 3          Devon Achane     297.0      1.324240       1        Isiah Pacheco
# 4   Christian McCaffrey     288.0      1.280557       1        Jaylen Warren
# 5         Derrick Henry     275.0      1.217460       1       Brian Robinson
# 6           Josh Jacobs     275.0      1.217460       1        Kaleb Johnson
# 7         Ashton Jeanty     274.0      1.212607       1        Austin Ekeler
# 8           Chase Brown     268.0      1.183485       1     Javonte Williams
# 9          Bucky Irving     265.0      1.168924       2  Rhamondre Stevenson
# 10       Kyren Williams     259.0      1.139802       2       Travis Etienne
# 11      Jonathan Taylor     255.0      1.120387       2      Zach Charbonnet
# 12         Alvin Kamara     253.0      1.110680       2         J.K. Dobbins
# 13          Breece Hall     242.0      1.057290       2         Tyjae Spears
# 14           James Cook     241.0      1.052436       2        Rachaad White
# 15   Kenneth Walker III     235.0      1.023315       2     Quinshon Judkins
# 16        Chuba Hubbard     234.0      1.018461       2         Najee Harris
# 17         James Conner     227.0      0.984485       2         Cam Skattebo
# 18      Omarion Hampton     222.0      0.960217       3          Jerome Ford
# 19        D'Andre Swift     215.0      0.926242       3         Jordan Mason
# 20   TreVeyon Henderson     210.0      0.901974       3          Tank Bigsby
# 21          Aaron Jones     206.0      0.882559       3          Rico Dowdle
# 22         Tony Pollard     203.0      0.867998       3          Jaydon Blue
# 23            RJ Harvey     200.0      0.853437       3            Ray Davis
#
#     points_2  tier_score_2  tier_2            player_3  points_3  \
# 0      199.0      0.848584       3      Tyler Allgeier     102.0
# 1      195.0      0.829169       3        Justice Hill     102.0
# 2      191.0      0.809754       3         Trey Benson     101.0
# 3      180.0      0.756364       4      Isaac Guerendo      99.8
# 4      176.0      0.736950       4         Kareem Hunt      97.4
# 5      173.0      0.722389       4     Roschon Johnson      95.5
# 6      171.0      0.712682       4          Nick Chubb      93.6
# 7      157.0      0.644731       4      Bhayshul Tuten      93.0
# 8      155.0      0.635023       4       Braelon Allen      90.5
# 9      151.0      0.615609       4           Zack Moss      88.1
# 10     151.0      0.615609       4       Jaylen Wright      87.3
# 11     149.0      0.605901       4       Dylan Sampson      86.8
# 12     147.0      0.596194       5       Miles Sanders      77.8
# 13     143.0      0.576780       5      MarShawn Lloyd      76.7
# 14     138.0      0.552511       5          Ty Johnson      75.8
# 15     137.0      0.547658       5       Samaje Perine      75.3
# 16     132.0      0.523390       5       Kendre Miller      73.5
# 17     126.0      0.494268       5      Raheem Mostert      73.2
# 18     124.0      0.484560       5  Alexander Mattison      68.3
# 19     121.0      0.470000       5         Gus Edwards      64.8
# 20     117.0      0.450585       5      Ameer Abdullah      63.3
# 21     110.0      0.416610       6         Woody Marks      62.2
# 22     108.0      0.406902       6    Devin Singletary      61.6
# 23     105.0      0.392341       6      Antonio Gibson      59.5
#
#     tier_score_3  tier_3
# 0       0.377780       6
# 1       0.377780       6
# 2       0.372927       6
# 3       0.367102       6
# 4       0.355454       6
# 5       0.346232       6
# 6       0.337010       7
# 7       0.334098       7
# 8       0.321964       7
# 9       0.310315       7
# 10      0.306432       7
# 11      0.304005       7
# 12      0.260322       7
# 13      0.254983       7
# 14      0.250615       7
# 15      0.248188       8
# 16      0.239452       8
# 17      0.237996       8
# 18      0.214213       8
# 19      0.197225       8
# 20      0.189945       8
# 21      0.184606       8
# 22      0.181693       8
# 23      0.171501       8

# %%
def show_tiers_multi(df: pd.DataFrame, position: str, n: int = 30, per_col: int = 15):
    """
    Show top n players for a given position in multiple columns.
    Each column has `per_col` rows. Handles uneven last column.
    """
    # Get sorted slice (tier first, then score/points)
    table = (
        df.loc[df['position'] == position, ['player','points','tier_score','tier']]
          .sort_values(by=['tier','tier_score'], ascending=[True, False])
          .head(n)
          .reset_index(drop=True)
    )
    
    # Split into chunks
    chunks = [table.iloc[i:i+per_col].reset_index(drop=True) 
              for i in range(0, len(table), per_col)]
    
    # Rename columns for each chunk
    renamed = []
    for idx, c in enumerate(chunks, 1):
        c.columns = [f'player_{idx}', f'points_{idx}', f'tier_score_{idx}', f'tier_{idx}']
        renamed.append(c)
    
    return pd.concat(renamed, axis=1)

# Option A.1 - heavier reliability weight
proj_current['tier_score_A1'] = (
    (proj_current['points'] - proj_current['bias'])
    * (proj_current['reliability'] ** 2)
    / (proj_current['abs_miss'] + 1e-6)
)

proj_tiers_A1 = assign_tiers_by_position(
    proj_current[['player','position','points','adj_points','tier_score_A1']]
    .rename(columns={'tier_score_A1':'tier_score'})
)

# Example: top 72 QBs, 24 per column
show_tiers_multi(proj_tiers_A1, 'QB', n=36, per_col=12)
# Out:
#            player_1  points_1  tier_score_1  tier_1          player_2  \
# 0     Lamar Jackson     438.0      1.913933       1    Justin Herbert
# 1        Josh Allen     432.0      1.882741       1      Dak Prescott
# 2        Joe Burrow     415.0      1.794363       1     Justin Fields
# 3    Jayden Daniels     412.0      1.778767       1     J.J. McCarthy
# 4       Jalen Hurts     398.0      1.705985       1       Jordan Love
# 5    Baker Mayfield     377.0      1.596812       1       C.J. Stroud
# 6   Patrick Mahomes     376.0      1.591614       2        Drake Maye
# 7      Kyler Murray     361.0      1.513633       2   Trevor Lawrence
# 8            Bo Nix     356.0      1.487640       2  Matthew Stafford
# 9       Brock Purdy     352.0      1.466845       2    Tua Tagovailoa
# 10       Jared Goff     346.0      1.435653       2       Bryce Young
# 11   Caleb Williams     340.0      1.404460       2        Geno Smith
#
#     points_2  tier_score_2  tier_2            player_3  points_3  \
# 0      338.0      1.394063       3   Michael Penix Jr.     298.0
# 1      336.0      1.383666       3       Aaron Rodgers     293.0
# 2      333.0      1.368070       3         Sam Darnold     290.0
# 3      323.0      1.316083       3            Cam Ward     279.0
# 4      323.0      1.316083       3  Anthony Richardson     237.0
# 5      320.0      1.300486       3      Russell Wilson     223.0
# 6      319.0      1.295288       4        Tyler Shough     168.0
# 7      318.0      1.290089       4        Daniel Jones     125.0
# 8      309.0      1.243301       4          Joe Flacco     118.0
# 9      306.0      1.227705       4     Spencer Rattler     108.0
# 10     302.0      1.206910       4        Kirk Cousins     100.0
# 11     302.0      1.206910       4       Kenny Pickett      78.2
#
#     tier_score_3  tier_3
# 0       1.186115       5
# 1       1.160122       5
# 2       1.144525       5
# 3       1.087340       5
# 4       0.868994       5
# 5       0.796213       5
# 6       0.510284       6
# 7       0.286740       6
# 8       0.250349       6
# 9       0.198362       6
# 10      0.156772       6
# 11      0.043441       6

# %%
def show_tiers_multi(df: pd.DataFrame, position: str, n: int = 30, per_col: int = 15):
    """
    Show top n players for a given position in multiple columns.
    Each column has `per_col` rows. Handles uneven last column.
    """
    # Get sorted slice (tier first, then score/points)
    table = (
        df.loc[df['position'] == position, ['player','points','tier_score','tier']]
          .sort_values(by=['tier','tier_score'], ascending=[True, False])
          .head(n)
          .reset_index(drop=True)
    )
    
    # Split into chunks
    chunks = [table.iloc[i:i+per_col].reset_index(drop=True) 
              for i in range(0, len(table), per_col)]
    
    # Rename columns for each chunk
    renamed = []
    for idx, c in enumerate(chunks, 1):
        c.columns = [f'player_{idx}', f'points_{idx}', f'tier_score_{idx}', f'tier_{idx}']
        renamed.append(c)
    
    return pd.concat(renamed, axis=1)

# Option A.1 - heavier reliability weight
proj_current['tier_score_A1'] = (
    (proj_current['points'] - proj_current['bias'])
    * (proj_current['reliability'] ** 2)
    / (proj_current['abs_miss'] + 1e-6)
)

proj_tiers_A1 = assign_tiers_by_position(
    proj_current[['player','position','points','adj_points','tier_score_A1']]
    .rename(columns={'tier_score_A1':'tier_score'})
)

# Example: top 72 TEs, 24 per column
show_tiers_multi(proj_tiers_A1, 'TE', n=36, per_col=12)
# Out:
#           player_1  points_1  tier_score_1  tier_1           player_2  \
# 0     Brock Bowers     259.0      1.842044       1     Dallas Goedert
# 1     Trey McBride     254.0      1.802940       1        Jonnu Smith
# 2    George Kittle     229.0      1.607421       1   Colston Loveland
# 3      Sam LaPorta     195.0      1.341515       1          Zach Ertz
# 4     Travis Kelce     185.0      1.263307       1       Hunter Henry
# 5   T.J. Hockenson     183.0      1.247666       1         Kyle Pitts
# 6     Mark Andrews     180.0      1.224203       1     Dalton Kincaid
# 7      David Njoku     173.0      1.169458       1         Cade Otton
# 8      Evan Engram     164.0      1.099071       2      Darren Waller
# 9     Tucker Kraft     157.0      1.044326       2    Brenton Strange
# 10    Tyler Warren     155.0      1.028684       2  Chigoziem Okonkwo
# 11   Jake Ferguson     153.0      1.013043       2     Pat Freiermuth
#
#     points_2  tier_score_2  tier_2           player_3  points_3  tier_score_3  \
# 0      152.0      1.005222       2       Mike Gesicki     130.0      0.833165
# 1      147.0      0.966118       2     Dalton Schultz     129.0      0.825344
# 2      147.0      0.966118       2      Isaiah Likely     127.0      0.809703
# 3      145.0      0.950477       3      Juwan Johnson     125.0      0.794061
# 4      144.0      0.942656       3       Tyler Higbee     124.0      0.786240
# 5      141.0      0.919194       3       Theo Johnson     117.0      0.731495
# 6      140.0      0.911373       3       Mason Taylor     116.0      0.723674
# 7      136.0      0.880090       3       Robbie Ouzts     113.0      0.700212
# 8      133.0      0.856627       3      Elijah Arroyo     106.0      0.645467
# 9      133.0      0.856627       3  Ja'Tavion Sanders      97.0      0.575080
# 10     132.0      0.848807       4        Will Dissly      95.3      0.561784
# 11     132.0      0.848807       4          Noah Gray      91.6      0.532848
#
#     tier_3
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5
# 11       5

# %% [markdown]
# ##### Option A.2 — normalize within position

# %%
# Option A.2 - normalize within position
proj_current['pos_mean'] = proj_current.groupby('position')['points'].transform('mean')

# % above positional mean using adjusted points
proj_current['adj_pct_above'] = (proj_current['adj_points'] - proj_current['pos_mean']) / proj_current['pos_mean']

proj_current['tier_score_A2'] = proj_current['adj_pct_above'] * proj_current['reliability']

# %%
proj_tiers_A2 = assign_tiers_by_position(
    proj_current[['player','position','points','adj_points','tier_score_A2']]
    .rename(columns={'tier_score_A2':'tier_score'})
)

# %%
# Example: top 72 RBs, 24 per column
show_tiers_multi(proj_tiers_A2, 'RB', n=72, per_col=24)
# Out:
#                player_1  points_1  tier_score_1  tier_1             player_2  \
# 0        Bijan Robinson     332.0      0.013588       1     David Montgomery
# 1        Saquon Barkley     319.0     -0.009720       1            Joe Mixon
# 2          Jahmyr Gibbs     318.0     -0.011513       1         Tyrone Tracy
# 3          Devon Achane     297.0     -0.049164       1        Isiah Pacheco
# 4   Christian McCaffrey     288.0     -0.065301       1        Jaylen Warren
# 5         Derrick Henry     275.0     -0.088609       1       Brian Robinson
# 6           Josh Jacobs     275.0     -0.088609       1        Kaleb Johnson
# 7         Ashton Jeanty     274.0     -0.090402       1        Austin Ekeler
# 8           Chase Brown     268.0     -0.101159       1     Javonte Williams
# 9          Bucky Irving     265.0     -0.106538       2  Rhamondre Stevenson
# 10       Kyren Williams     259.0     -0.117296       2       Travis Etienne
# 11      Jonathan Taylor     255.0     -0.124467       2      Zach Charbonnet
# 12         Alvin Kamara     253.0     -0.128053       2         J.K. Dobbins
# 13          Breece Hall     242.0     -0.147775       2         Tyjae Spears
# 14           James Cook     241.0     -0.149568       2        Rachaad White
# 15   Kenneth Walker III     235.0     -0.160326       2     Quinshon Judkins
# 16        Chuba Hubbard     234.0     -0.162119       2         Najee Harris
# 17         James Conner     227.0     -0.174669       2         Cam Skattebo
# 18      Omarion Hampton     222.0     -0.183634       3          Jerome Ford
# 19        D'Andre Swift     215.0     -0.196185       3         Jordan Mason
# 20   TreVeyon Henderson     210.0     -0.205149       3          Tank Bigsby
# 21          Aaron Jones     206.0     -0.212321       3          Rico Dowdle
# 22         Tony Pollard     203.0     -0.217700       3          Jaydon Blue
# 23            RJ Harvey     200.0     -0.223079       3            Ray Davis
#
#     points_2  tier_score_2  tier_2            player_3  points_3  \
# 0      199.0     -0.224871       3      Tyler Allgeier     102.0
# 1      195.0     -0.232043       3        Justice Hill     102.0
# 2      191.0     -0.239215       3         Trey Benson     101.0
# 3      180.0     -0.258937       4      Isaac Guerendo      99.8
# 4      176.0     -0.266109       4         Kareem Hunt      97.4
# 5      173.0     -0.271488       4     Roschon Johnson      95.5
# 6      171.0     -0.275074       4          Nick Chubb      93.6
# 7      157.0     -0.300175       4      Bhayshul Tuten      93.0
# 8      155.0     -0.303760       4       Braelon Allen      90.5
# 9      151.0     -0.310932       4           Zack Moss      88.1
# 10     151.0     -0.310932       4       Jaylen Wright      87.3
# 11     149.0     -0.314518       4       Dylan Sampson      86.8
# 12     147.0     -0.318104       5       Miles Sanders      77.8
# 13     143.0     -0.325276       5      MarShawn Lloyd      76.7
# 14     138.0     -0.334240       5          Ty Johnson      75.8
# 15     137.0     -0.336033       5       Samaje Perine      75.3
# 16     132.0     -0.344998       5       Kendre Miller      73.5
# 17     126.0     -0.355756       5      Raheem Mostert      73.2
# 18     124.0     -0.359341       5  Alexander Mattison      68.3
# 19     121.0     -0.364720       5         Gus Edwards      64.8
# 20     117.0     -0.371892       5      Ameer Abdullah      63.3
# 21     110.0     -0.384442       6         Woody Marks      62.2
# 22     108.0     -0.388028       6    Devin Singletary      61.6
# 23     105.0     -0.393407       6      Antonio Gibson      59.5
#
#     tier_score_3  tier_3
# 0      -0.398786       6
# 1      -0.398786       6
# 2      -0.400579       6
# 3      -0.402730       6
# 4      -0.407033       6
# 5      -0.410440       6
# 6      -0.413847       7
# 7      -0.414922       7
# 8      -0.419405       7
# 9      -0.423708       7
# 10     -0.425142       7
# 11     -0.426038       7
# 12     -0.442175       7
# 13     -0.444147       7
# 14     -0.445761       7
# 15     -0.446657       8
# 16     -0.449884       8
# 17     -0.450422       8
# 18     -0.459208       8
# 19     -0.465483       8
# 20     -0.468172       8
# 21     -0.470145       8
# 22     -0.471220       8
# 23     -0.474985       8

# %%
# Example: top 72 WRs, 24 per column
show_tiers_multi(proj_tiers_A2, 'WR', n=72, per_col=24)
# Out:
#                player_1  points_1  tier_score_1  tier_1           player_2  \
# 0         Ja'Marr Chase     355.0      0.027659       1        Zay Flowers
# 1      Justin Jefferson     317.0     -0.052945       1      Calvin Ridley
# 2           CeeDee Lamb     312.0     -0.063551       1        Jerry Jeudy
# 3            Puka Nacua     305.0     -0.078399       1        Rashee Rice
# 4          Malik Nabers     302.0     -0.084763       1   Jameson Williams
# 5     Amon-Ra St. Brown     298.0     -0.093248       1      Jaylen Waddle
# 6          Nico Collins     287.0     -0.116580       1      Jakobi Meyers
# 7      Brian Thomas Jr.     284.0     -0.122944       1     George Pickens
# 8          Drake London     268.0     -0.156883       2      Travis Hunter
# 9            A.J. Brown     265.0     -0.163246       2      Travis Hunter
# 10          Tyreek Hill     263.0     -0.167489       2  Tetairoa McMillan
# 11        Ladd McConkey     262.0     -0.169610       2        Chris Olave
# 12   Jaxon Smith-Njigba     255.0     -0.184458       2        Rome Odunze
# 13        Davante Adams     251.0     -0.192943       2       Deebo Samuel
# 14          Tee Higgins     251.0     -0.192943       2     Jauan Jennings
# 15       Terry McLaurin     247.0     -0.201427       3       Chris Godwin
# 16           Mike Evans     246.0     -0.203549       3       Stefon Diggs
# 17       Garrett Wilson     244.0     -0.207791       3      Khalil Shakir
# 18           D.J. Moore     241.0     -0.214154       3        Cooper Kupp
# 19  Marvin Harrison Jr.     237.0     -0.222639       3        Jayden Reed
# 20           DK Metcalf     233.0     -0.231124       3     Jordan Addison
# 21     Courtland Sutton     230.0     -0.237487       3     Matthew Golden
# 22        DeVonta Smith     229.0     -0.239609       4    Michael Pittman
# 23        Xavier Worthy     226.0     -0.245972       4     Ricky Pearsall
#
#     points_2  tier_score_2  tier_2           player_3  points_3  tier_score_3  \
# 0      221.0     -0.256578       4         Josh Downs     179.0     -0.345667
# 1      221.0     -0.256578       4     Darnell Mooney     178.0     -0.347789
# 2      219.0     -0.260820       4     Rashid Shaheed     172.0     -0.360516
# 3      215.0     -0.269305       4       Keon Coleman     168.0     -0.369000
# 4      214.0     -0.271426       4       Keenan Allen     161.0     -0.383849
# 5      211.0     -0.277790       5       Adam Thielen     160.0     -0.385970
# 6      210.0     -0.279911       5  Wan'Dale Robinson     157.0     -0.392333
# 7      209.0     -0.282032       5     Rashod Bateman     153.0     -0.400818
# 8      207.0     -0.286274       5        Marvin Mims     153.0     -0.400818
# 9      207.0     -0.286274       5       Emeka Egbuka     152.0     -0.402939
# 10     207.0     -0.286274       5      Brandon Aiyuk     147.0     -0.413545
# 11     203.0     -0.294759       5     Cedric Tillman     147.0     -0.413545
# 12     203.0     -0.294759       5       Amari Cooper     145.0     -0.417787
# 13     200.0     -0.301123       6     Xavier Legette     144.0     -0.419908
# 14     199.0     -0.303244       6    Demario Douglas     143.0     -0.422030
# 15     199.0     -0.303244       6     Marquise Brown     142.0     -0.424151
# 16     196.0     -0.309607       6        Romeo Doubs     142.0     -0.424151
# 17     191.0     -0.320213       6     Jayden Higgins     140.0     -0.428393
# 18     190.0     -0.322334       6     Christian Kirk     140.0     -0.428393
# 19     189.0     -0.324456       6   Quentin Johnston     139.0     -0.430514
# 20     189.0     -0.324456       7     Michael Wilson     135.0     -0.438999
# 21     187.0     -0.328698       7      Luther Burden     126.0     -0.458090
# 22     185.0     -0.332940       7        Alec Pierce     125.0     -0.460211
# 23     185.0     -0.332940       7          Jack Bech     121.0     -0.468696
#
#     tier_3
# 0        7
# 1        7
# 2        7
# 3        8
# 4        8
# 5        8
# 6        8
# 7        8
# 8        8
# 9        8
# 10       9
# 11       9
# 12       9
# 13       9
# 14       9
# 15       9
# 16       9
# 17      10
# 18      10
# 19      10
# 20      10
# 21      10
# 22      10
# 23      10

# %%
# Example: top 72 WRs, 24 per column
show_tiers_multi(proj_tiers_A2, 'QB', n=36, per_col=12)
# Out:
#            player_1  points_1  tier_score_1  tier_1          player_2  \
# 0     Lamar Jackson     438.0     -0.105300       1    Justin Herbert
# 1        Josh Allen     432.0     -0.114775       1      Dak Prescott
# 2        Joe Burrow     415.0     -0.141620       1     Justin Fields
# 3    Jayden Daniels     412.0     -0.146358       1     J.J. McCarthy
# 4       Jalen Hurts     398.0     -0.168465       1       Jordan Love
# 5    Baker Mayfield     377.0     -0.201627       1       C.J. Stroud
# 6   Patrick Mahomes     376.0     -0.203206       2        Drake Maye
# 7      Kyler Murray     361.0     -0.226893       2   Trevor Lawrence
# 8            Bo Nix     356.0     -0.234789       2  Matthew Stafford
# 9       Brock Purdy     352.0     -0.241105       2    Tua Tagovailoa
# 10       Jared Goff     346.0     -0.250580       2       Bryce Young
# 11   Caleb Williams     340.0     -0.260055       2        Geno Smith
#
#     points_2  tier_score_2  tier_2            player_3  points_3  \
# 0      338.0     -0.263213       3   Michael Penix Jr.     298.0
# 1      336.0     -0.266371       3       Aaron Rodgers     293.0
# 2      333.0     -0.271109       3         Sam Darnold     290.0
# 3      323.0     -0.286900       3            Cam Ward     279.0
# 4      323.0     -0.286900       3  Anthony Richardson     237.0
# 5      320.0     -0.291637       3      Russell Wilson     223.0
# 6      319.0     -0.293217       4        Tyler Shough     168.0
# 7      318.0     -0.294796       4        Daniel Jones     125.0
# 8      309.0     -0.309008       4          Joe Flacco     118.0
# 9      306.0     -0.313745       4     Spencer Rattler     108.0
# 10     302.0     -0.320062       4        Kirk Cousins     100.0
# 11     302.0     -0.320062       4       Kenny Pickett      78.2
#
#     tier_score_3  tier_3
# 0      -0.326378       5
# 1      -0.334274       5
# 2      -0.339011       5
# 3      -0.356382       5
# 4      -0.422705       5
# 5      -0.444813       5
# 6      -0.531665       6
# 7      -0.599568       6
# 8      -0.610621       6
# 9      -0.626413       6
# 10     -0.639046       6
# 11     -0.673471       6

# %%
# Example: top 72 WRs, 24 per column
show_tiers_multi(proj_tiers_A2, 'TE', n=36, per_col=12)
# Out:
#           player_1  points_1  tier_score_1  tier_1           player_2  \
# 0     Brock Bowers     259.0     -0.024925       1     Dallas Goedert
# 1     Trey McBride     254.0     -0.037213       1        Jonnu Smith
# 2    George Kittle     229.0     -0.098653       1   Colston Loveland
# 3      Sam LaPorta     195.0     -0.182211       1          Zach Ertz
# 4     Travis Kelce     185.0     -0.206787       1       Hunter Henry
# 5   T.J. Hockenson     183.0     -0.211702       1         Kyle Pitts
# 6     Mark Andrews     180.0     -0.219075       1     Dalton Kincaid
# 7      David Njoku     173.0     -0.236278       1         Cade Otton
# 8      Evan Engram     164.0     -0.258397       2      Darren Waller
# 9     Tucker Kraft     157.0     -0.275600       2    Brenton Strange
# 10    Tyler Warren     155.0     -0.280515       2  Chigoziem Okonkwo
# 11   Jake Ferguson     153.0     -0.285430       2     Pat Freiermuth
#
#     points_2  tier_score_2  tier_2           player_3  points_3  tier_score_3  \
# 0      152.0     -0.287888       2       Mike Gesicki     130.0     -0.341955
# 1      147.0     -0.300176       2     Dalton Schultz     129.0     -0.344413
# 2      147.0     -0.300176       2      Isaiah Likely     127.0     -0.349328
# 3      145.0     -0.305091       3      Juwan Johnson     125.0     -0.354243
# 4      144.0     -0.307549       3       Tyler Higbee     124.0     -0.356701
# 5      141.0     -0.314921       3       Theo Johnson     117.0     -0.373904
# 6      140.0     -0.317379       3       Mason Taylor     116.0     -0.376361
# 7      136.0     -0.327209       3       Robbie Ouzts     113.0     -0.383734
# 8      133.0     -0.334582       3      Elijah Arroyo     106.0     -0.400937
# 9      133.0     -0.334582       3  Ja'Tavion Sanders      97.0     -0.423056
# 10     132.0     -0.337040       4        Will Dissly      95.3     -0.427234
# 11     132.0     -0.337040       4          Noah Gray      91.6     -0.436327
#
#     tier_3
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5
# 11       5

# %%
# Option A.3 - add uncertainty bands
proj_current['floor_A3']   = proj_current['adj_points'] - proj_current['abs_miss']
proj_current['ceiling_A3'] = proj_current['adj_points'] + proj_current['abs_miss']

# Floor-based score
proj_current['tier_score_A3_floor'] = proj_current['floor_A3'] * proj_current['reliability']

# Ceiling-based score
proj_current['tier_score_A3_ceiling'] = proj_current['ceiling_A3'] * proj_current['reliability']

# Floor tiers
proj_tiers_A3_floor = assign_tiers_by_position(
    proj_current[['player','position','points','adj_points','tier_score_A3_floor']]
    .rename(columns={'tier_score_A3_floor':'tier_score'})
)

# Ceiling tiers
proj_tiers_A3_ceiling = assign_tiers_by_position(
    proj_current[['player','position','points','adj_points','tier_score_A3_ceiling']]
    .rename(columns={'tier_score_A3_ceiling':'tier_score'})
)

# %%
# Top 60 WRs by floor (safe)
show_tiers_multi(proj_tiers_A3_floor, 'WR', n=60, per_col=20)
# Out:
#                player_1  points_1  tier_score_1  tier_1           player_2  \
# 0         Ja'Marr Chase     355.0    102.711566       1         DK Metcalf
# 1      Justin Jefferson     317.0     86.199757       1   Courtland Sutton
# 2           CeeDee Lamb     312.0     84.027150       1      DeVonta Smith
# 3            Puka Nacua     305.0     80.985501       1      Xavier Worthy
# 4          Malik Nabers     302.0     79.681937       1        Zay Flowers
# 5     Amon-Ra St. Brown     298.0     77.943852       1      Calvin Ridley
# 6          Nico Collins     287.0     73.164118       1        Jerry Jeudy
# 7      Brian Thomas Jr.     284.0     71.860554       1        Rashee Rice
# 8          Drake London     268.0     64.908213       2   Jameson Williams
# 9            A.J. Brown     265.0     63.604650       2      Jaylen Waddle
# 10          Tyreek Hill     263.0     62.735607       2      Jakobi Meyers
# 11        Ladd McConkey     262.0     62.301086       2     George Pickens
# 12   Jaxon Smith-Njigba     255.0     59.259437       2      Travis Hunter
# 13        Davante Adams     251.0     57.521352       2      Travis Hunter
# 14          Tee Higgins     251.0     57.521352       2  Tetairoa McMillan
# 15       Terry McLaurin     247.0     55.783266       3        Chris Olave
# 16           Mike Evans     246.0     55.348745       3        Rome Odunze
# 17       Garrett Wilson     244.0     54.479702       3       Deebo Samuel
# 18           D.J. Moore     241.0     53.176139       3     Jauan Jennings
# 19  Marvin Harrison Jr.     237.0     51.438053       3       Chris Godwin
#
#     points_2  tier_score_2  tier_2           player_3  points_3  tier_score_3  \
# 0      233.0     49.699968       3       Stefon Diggs     196.0     33.622680
# 1      230.0     48.396404       3      Khalil Shakir     191.0     31.450074
# 2      229.0     47.961883       4        Cooper Kupp     190.0     31.015553
# 3      226.0     46.658319       4        Jayden Reed     189.0     30.581031
# 4      221.0     44.485713       4     Jordan Addison     189.0     30.581031
# 5      221.0     44.485713       4     Matthew Golden     187.0     29.711989
# 6      219.0     43.616670       4    Michael Pittman     185.0     28.842946
# 7      215.0     41.878585       4     Ricky Pearsall     185.0     28.842946
# 8      214.0     41.444064       4         Josh Downs     179.0     26.235819
# 9      211.0     40.140500       5     Darnell Mooney     178.0     25.801297
# 10     210.0     39.705979       5     Rashid Shaheed     172.0     23.194170
# 11     209.0     39.271457       5       Keon Coleman     168.0     21.456084
# 12     207.0     38.402415       5       Keenan Allen     161.0     18.414435
# 13     207.0     38.402415       5       Adam Thielen     160.0     17.979914
# 14     207.0     38.402415       5  Wan'Dale Robinson     157.0     16.676350
# 15     203.0     36.664330       5     Rashod Bateman     153.0     14.938265
# 16     203.0     36.664330       5        Marvin Mims     153.0     14.938265
# 17     200.0     35.360766       6       Emeka Egbuka     152.0     14.503744
# 18     199.0     34.926244       6      Brandon Aiyuk     147.0     12.331137
# 19     199.0     34.926244       6     Cedric Tillman     147.0     12.331137
#
#     tier_3
# 0        6
# 1        6
# 2        6
# 3        6
# 4        7
# 5        7
# 6        7
# 7        7
# 8        7
# 9        7
# 10       7
# 11       8
# 12       8
# 13       8
# 14       8
# 15       8
# 16       8
# 17       8
# 18       9
# 19       9

# %%
# Top 60 WRs by ceiling (upside)
show_tiers_multi(proj_tiers_A3_ceiling, 'WR', n=60, per_col=20)
# Out:
#                player_1  points_1  tier_score_1  tier_1           player_2  \
# 0         Ja'Marr Chase     355.0    178.686568       1         DK Metcalf
# 1      Justin Jefferson     317.0    162.174759       1   Courtland Sutton
# 2           CeeDee Lamb     312.0    160.002153       1      DeVonta Smith
# 3            Puka Nacua     305.0    156.960504       1      Xavier Worthy
# 4          Malik Nabers     302.0    155.656940       1        Zay Flowers
# 5     Amon-Ra St. Brown     298.0    153.918854       1      Calvin Ridley
# 6          Nico Collins     287.0    149.139120       1        Jerry Jeudy
# 7      Brian Thomas Jr.     284.0    147.835556       1        Rashee Rice
# 8          Drake London     268.0    140.883216       2   Jameson Williams
# 9            A.J. Brown     265.0    139.579652       2      Jaylen Waddle
# 10          Tyreek Hill     263.0    138.710609       2      Jakobi Meyers
# 11        Ladd McConkey     262.0    138.276088       2     George Pickens
# 12   Jaxon Smith-Njigba     255.0    135.234439       2      Travis Hunter
# 13        Davante Adams     251.0    133.496354       2      Travis Hunter
# 14          Tee Higgins     251.0    133.496354       2  Tetairoa McMillan
# 15       Terry McLaurin     247.0    131.758269       3        Chris Olave
# 16           Mike Evans     246.0    131.323747       3        Rome Odunze
# 17       Garrett Wilson     244.0    130.454705       3       Deebo Samuel
# 18           D.J. Moore     241.0    129.151141       3     Jauan Jennings
# 19  Marvin Harrison Jr.     237.0    127.413056       3       Chris Godwin
#
#     points_2  tier_score_2  tier_2           player_3  points_3  tier_score_3  \
# 0      233.0    125.674971       3       Stefon Diggs     196.0    109.597683
# 1      230.0    124.371407       3      Khalil Shakir     191.0    107.425076
# 2      229.0    123.936885       4        Cooper Kupp     190.0    106.990555
# 3      226.0    122.633322       4        Jayden Reed     189.0    106.556034
# 4      221.0    120.460715       4     Jordan Addison     189.0    106.556034
# 5      221.0    120.460715       4     Matthew Golden     187.0    105.686991
# 6      219.0    119.591672       4    Michael Pittman     185.0    104.817949
# 7      215.0    117.853587       4     Ricky Pearsall     185.0    104.817949
# 8      214.0    117.419066       4         Josh Downs     179.0    102.210821
# 9      211.0    116.115502       5     Darnell Mooney     178.0    101.776300
# 10     210.0    115.680981       5     Rashid Shaheed     172.0     99.169172
# 11     209.0    115.246460       5       Keon Coleman     168.0     97.431087
# 12     207.0    114.377417       5       Keenan Allen     161.0     94.389438
# 13     207.0    114.377417       5       Adam Thielen     160.0     93.954916
# 14     207.0    114.377417       5  Wan'Dale Robinson     157.0     92.651352
# 15     203.0    112.639332       5     Rashod Bateman     153.0     90.913267
# 16     203.0    112.639332       5        Marvin Mims     153.0     90.913267
# 17     200.0    111.335768       6       Emeka Egbuka     152.0     90.478746
# 18     199.0    110.901247       6      Brandon Aiyuk     147.0     88.306140
# 19     199.0    110.901247       6     Cedric Tillman     147.0     88.306140
#
#     tier_3
# 0        6
# 1        6
# 2        6
# 3        6
# 4        7
# 5        7
# 6        7
# 7        7
# 8        7
# 9        7
# 10       7
# 11       8
# 12       8
# 13       8
# 14       8
# 15       8
# 16       8
# 17       8
# 18       9
# 19       9

# %%
# Weights for blending (you can tune these)
w_bias    = 1.0    # how strongly to correct for bias
w_rel     = 2.0    # reliability weight (use squared)
w_norm    = 1.0    # how much to scale by % above position mean
w_floor   = 0.5    # weight on floor (safety)
w_ceiling = 0.5    # weight on ceiling (upside)

# Normalization already computed in A.2
proj_current['pos_mean'] = proj_current.groupby('position')['points'].transform('mean')
proj_current['adj_pct_above'] = (proj_current['adj_points'] - proj_current['pos_mean']) / proj_current['pos_mean']

# Floor & ceiling already computed in A.3
proj_current['floor_A3']   = proj_current['adj_points'] - proj_current['abs_miss']
proj_current['ceiling_A3'] = proj_current['adj_points'] + proj_current['abs_miss']

# Fused score
proj_current['tier_score_A4'] = (
    ((proj_current['points'] - w_bias * proj_current['bias']) *
     (proj_current['reliability'] ** w_rel)) +
    (w_norm * proj_current['adj_pct_above'] * 100) +         # scale to %
    (w_floor * proj_current['floor_A3']) +
    (w_ceiling * proj_current['ceiling_A3'])
)

# %%
proj_tiers_A4 = assign_tiers_by_position(
    proj_current[['player','position','points','adj_points','tier_score_A4']]
    .rename(columns={'tier_score_A4':'tier_score'})
)

# %%
# Example: top 72 WRs, 24 per column under fused A.4
show_tiers_multi(proj_tiers_A4, 'WR', n=72, per_col=24)
# Out:
#                player_1  points_1  tier_score_1  tier_1           player_2  \
# 0         Ja'Marr Chase     355.0    358.339950       1        Zay Flowers
# 1      Justin Jefferson     317.0    304.551237       1      Calvin Ridley
# 2           CeeDee Lamb     312.0    297.473774       1        Jerry Jeudy
# 3            Puka Nacua     305.0    287.565327       1        Rashee Rice
# 4          Malik Nabers     302.0    283.318850       1   Jameson Williams
# 5     Amon-Ra St. Brown     298.0    277.656880       1      Jaylen Waddle
# 6          Nico Collins     287.0    262.086463       1      Jakobi Meyers
# 7      Brian Thomas Jr.     284.0    257.839986       1     George Pickens
# 8          Drake London     268.0    235.192107       2      Travis Hunter
# 9            A.J. Brown     265.0    230.945629       2      Travis Hunter
# 10          Tyreek Hill     263.0    228.114644       2  Tetairoa McMillan
# 11        Ladd McConkey     262.0    226.699152       2        Chris Olave
# 12   Jaxon Smith-Njigba     255.0    216.790705       2        Rome Odunze
# 13        Davante Adams     251.0    211.128735       2       Deebo Samuel
# 14          Tee Higgins     251.0    211.128735       2     Jauan Jennings
# 15       Terry McLaurin     247.0    205.466765       3       Chris Godwin
# 16           Mike Evans     246.0    204.051273       3       Stefon Diggs
# 17       Garrett Wilson     244.0    201.220288       3      Khalil Shakir
# 18           D.J. Moore     241.0    196.973811       3        Cooper Kupp
# 19  Marvin Harrison Jr.     237.0    191.311841       3        Jayden Reed
# 20           DK Metcalf     233.0    185.649871       3     Jordan Addison
# 21     Courtland Sutton     230.0    181.403394       3     Matthew Golden
# 22        DeVonta Smith     229.0    179.987901       4    Michael Pittman
# 23        Xavier Worthy     226.0    175.741424       4     Ricky Pearsall
#
#     points_2  tier_score_2  tier_2           player_3  points_3  tier_score_3  \
# 0      221.0    168.663962       4         Josh Downs     179.0    109.213279
# 1      221.0    168.663962       4     Darnell Mooney     178.0    107.797786
# 2      219.0    165.832977       4     Rashid Shaheed     172.0     99.304832
# 3      215.0    160.171007       4       Keon Coleman     168.0     93.642862
# 4      214.0    158.755514       4       Keenan Allen     161.0     83.734415
# 5      211.0    154.509037       5       Adam Thielen     160.0     82.318922
# 6      210.0    153.093545       5  Wan'Dale Robinson     157.0     78.072445
# 7      209.0    151.678052       5     Rashod Bateman     153.0     72.410475
# 8      207.0    148.847067       5        Marvin Mims     153.0     72.410475
# 9      207.0    148.847067       5       Emeka Egbuka     152.0     70.994983
# 10     207.0    148.847067       5      Brandon Aiyuk     147.0     63.917520
# 11     203.0    143.185098       5     Cedric Tillman     147.0     63.917520
# 12     203.0    143.185098       5       Amari Cooper     145.0     61.086536
# 13     200.0    138.938620       6     Xavier Legette     144.0     59.671043
# 14     199.0    137.523128       6    Demario Douglas     143.0     58.255551
# 15     199.0    137.523128       6     Marquise Brown     142.0     56.840058
# 16     196.0    133.276650       6        Romeo Doubs     142.0     56.840058
# 17     191.0    126.199188       6     Jayden Higgins     140.0     54.009073
# 18     190.0    124.783696       6     Christian Kirk     140.0     54.009073
# 19     189.0    123.368203       6   Quentin Johnston     139.0     52.593581
# 20     189.0    123.368203       7     Michael Wilson     135.0     46.931611
# 21     187.0    120.537218       7      Luther Burden     126.0     34.192179
# 22     185.0    117.706233       7        Alec Pierce     125.0     32.776687
# 23     185.0    117.706233       7          Jack Bech     121.0     27.114717
#
#     tier_3
# 0        7
# 1        7
# 2        7
# 3        8
# 4        8
# 5        8
# 6        8
# 7        8
# 8        8
# 9        8
# 10       9
# 11       9
# 12       9
# 13       9
# 14       9
# 15       9
# 16       9
# 17      10
# 18      10
# 19      10
# 20      10
# 21      10
# 22      10
# 23      10

# %%
# Sort ALL players across positions by fused tier_score (Option A.4)
sorted_all = (
    proj_tiers_A4
    .sort_values(by='tier_score', ascending=False)
    .reset_index(drop=True)
)

# Add an overall rank column
sorted_all['overall_rank'] = range(1, len(sorted_all) + 1)

# Preview top 50 overall
sorted_all[['overall_rank','player','position','points','adj_points','tier_score','tier']].head(50)
# Out:
#     overall_rank               player position  points  adj_points  \
# 0              1        Lamar Jackson       QB   438.0  252.800332
# 1              2           Josh Allen       QB   432.0  248.680335
# 2              3           Joe Burrow       QB   415.0  237.007010
# 3              4       Jayden Daniels       QB   412.0  234.947012
# 4              5        Ja'Marr Chase       WR   355.0  213.444853
# 5              6          Jalen Hurts       QB   398.0  225.333685
# 6              7       Baker Mayfield       QB   377.0  210.913696
# 7              8      Patrick Mahomes       QB   376.0  210.227029
# 8              9     Justin Jefferson       WR   317.0  188.395926
# 9             10         Kyler Murray       QB   361.0  199.927037
# 10            11          CeeDee Lamb       WR   312.0  185.100015
# 11            12               Bo Nix       QB   356.0  196.493706
# 12            13          Brock Purdy       QB   352.0  193.747041
# 13            14           Puka Nacua       WR   305.0  180.485739
# 14            15           Jared Goff       QB   346.0  189.627044
# 15            16         Malik Nabers       WR   302.0  178.508192
# 16            17    Amon-Ra St. Brown       WR   298.0  175.871462
# 17            18       Caleb Williams       QB   340.0  185.507047
# 18            19       Justin Herbert       QB   338.0  184.133715
# 19            20         Dak Prescott       QB   336.0  182.760383
# 20            21        Justin Fields       QB   333.0  180.700384
# 21            22         Nico Collins       WR   287.0  168.620457
# 22            23     Brian Thomas Jr.       WR   284.0  166.642910
# 23            24       Bijan Robinson       RB   332.0  165.718905
# 24            25        J.J. McCarthy       QB   323.0  173.833722
# 25            26          Jordan Love       QB   323.0  173.833722
# 26            27          C.J. Stroud       QB   320.0  171.773724
# 27            28           Drake Maye       QB   319.0  171.087058
# 28            29      Trevor Lawrence       QB   318.0  170.400392
# 29            30       Saquon Barkley       RB   319.0  158.720514
# 30            31         Jahmyr Gibbs       RB   318.0  158.182177
# 31            32         Drake London       WR   268.0  156.095994
# 32            33     Matthew Stafford       QB   309.0  164.220396
# 33            34           A.J. Brown       WR   265.0  154.118447
# 34            35          Tyreek Hill       WR   263.0  152.800082
# 35            36       Tua Tagovailoa       QB   306.0  162.160398
# 36            37        Ladd McConkey       WR   262.0  152.140900
# 37            38         Brock Bowers       TE   259.0  142.207173
# 38            39          Bryce Young       QB   302.0  159.413733
# 39            40           Geno Smith       QB   302.0  159.413733
# 40            41         Trey McBride       TE   254.0  139.188328
# 41            42         Devon Achane       RB   297.0  146.877084
# 42            43   Jaxon Smith-Njigba       WR   255.0  147.526624
# 43            44    Michael Penix Jr.       QB   298.0  156.667068
# 44            45        Davante Adams       WR   251.0  144.889895
# 45            46          Tee Higgins       WR   251.0  144.889895
# 46            47        Aaron Rodgers       QB   293.0  153.233737
# 47            48  Christian McCaffrey       RB   288.0  142.032044
# 48            49          Sam Darnold       QB   290.0  151.173739
# 49            50       Terry McLaurin       WR   247.0  142.253166
#
#     tier_score  tier
# 0   411.054784     1
# 1   402.725902     1
# 2   379.127402     1
# 3   374.962961     1
# 4   358.339950     1
# 5   355.528903     1
# 6   326.377815     1
# 7   324.989668     2
# 8   304.551237     1
# 9   304.167462     2
# 10  297.473774     1
# 11  297.226727     2
# 12  291.674139     2
# 13  287.565327     1
# 14  283.345257     2
# 15  283.318850     1
# 16  277.656880     1
# 17  275.016375     2
# 18  272.240081     3
# 19  269.463787     3
# 20  265.299345     3
# 21  262.086463     1
# 22  257.839986     1
# 23  257.455804     1
# 24  251.417875     3
# 25  251.417875     3
# 26  247.253434     3
# 27  245.865287     4
# 28  244.477140     4
# 29  242.360270     1
# 30  241.199075     1
# 31  235.192107     2
# 32  231.983817     4
# 33  230.945629     2
# 34  228.114644     2
# 35  227.819376     4
# 36  226.699152     2
# 37  223.939260     1
# 38  222.266787     4
# 39  222.266787     4
# 40  217.062515     1
# 41  216.813981     1
# 42  216.790705     2
# 43  216.714199     5
# 44  211.128735     2
# 45  211.128735     2
# 46  209.773464     5
# 47  206.363226     1
# 48  205.609023     5
# 49  205.466765     3
